# %%
import numpy as np
import pyleoclim as pyleo
from pyleoclim.utils import spectral
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def generate_signal(ratio):
    freqs=[1/20,1/80]
    time=np.arange(5001)
    signals=[]
    for freq in freqs:
        signals.append(np.cos(2*np.pi*freq*time))
    signal=sum(signals)
    sig_var = np.var(signal)
    noise_var = sig_var*ratio#signal is twice the size of noise
    white_noise = np.random.normal(0, np.sqrt(noise_var), size=np.size(signal))
    signal_noise = signal + white_noise
    return time,signal_noise

# %%
time,signal = generate_signal(0)

# %%
plt.plot(time,signal)

# %%
res_welch =spectral.welch(time,signal,ana_args={'nperseg':len(time)/2})

# %%
res_periodogram = spectral.periodogram(time,signal)

# %%
plt.plot(res_welch['freq'],res_welch['psd'])

# %%
plt.plot(res_periodogram['freq'],res_periodogram['psd'])

# %%
time2,signal2 = generate_signal(2)

# %%
plt.plot(time2,signal2)

# %%
res_welch_2 = spectral.welch(time2,signal2,ana_args={'nperseg':len(time2)/2})

# %%
plt.plot(res_welch_2['freq'],res_welch_2['psd'])

# %%
res_periodogram_2 = spectral.periodogram(time2,signal2)

# %%
plt.plot(res_periodogram_2['freq'],res_periodogram_2['psd'])

# %%
time3,signal3 = generate_signal(4)

# %%
plt.plot(time3,signal3)

# %%
res_welch_3 = spectral.welch(time3,signal3,ana_args={'nperseg':len(time3)/2})

# %%
plt.plot(res_welch_3['freq'],res_welch_3['psd'])

# %%
res_periodogram_3 = spectral.periodogram(time3,signal3)

# %%
plt.plot(res_periodogram_3['freq'],res_periodogram_3['psd'])

# %%
time4,signal4 = generate_signal(6)

# %%
plt.plot(time4,signal4)

# %%
res_welch_4 = spectral.welch(time4,signal4,ana_args={'nperseg':len(time3)/2})

# %%
plt.plot(res_welch_4['freq']res_welch_4['psd'])
# Out:
# {'freq': array([0.00000000e+00, 1.04003638e-01, 2.08007276e-01, ...,
#         1.29796540e+02, 1.29900544e+02, 1.30004547e+02]),
#  'psd': array([       nan, 0.07834195, 0.03052086, ..., 0.00407873, 0.00137468,
#         0.00070528])}

# %%
res_periodogram_4 = spectral.periodogram(time4,signal4)

# %%
plt.plot(res_periodogram_4['freq'],res_periodogram_4['psd'])
