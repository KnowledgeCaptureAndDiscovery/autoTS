# %%
import numpy as np
import pyleoclim as pyleo
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Signal with periodictiy 1/50 having a length of 2000

# %%
t = np.arange(2001)
f = 1/50
signal = 2*np.cos(np.pi*f*t)

plt.plot(signal)

# %% [markdown]
# # Adding Linear Trend

# %%
time = np.arange(2001)
slope = 0.01
intercept = -1
linear_trend = slope*time + intercept
signal_linear = signal+linear_trend
plt.plot(signal_linear)

# %% [markdown]
# # Adding Polynomial Trend

# %%
time = np.arange(2001)
slope = 1e-5
intercept = -1
non_linear_trend = slope*time**2 + intercept
signal_non_linear = signal+non_linear_trend
plt.plot(signal_non_linear)

# %% [markdown]
# # Adding Cos Trend

# %%
time = np.arange(2001)
freq = 1/1500
signal2 = np.cos(2*np.pi*freq*time)
signal_cos = signal+3*signal2
sig_var = np.var(signal_cos)
noise_var = sig_var/ 2 #signal is twice the size of noise
white_noise = np.random.normal(0, np.sqrt(noise_var), size=np.size(signal_cos))
signal_cos = signal_cos+white_noise

plt.plot(signal_cos)

# %% [markdown]
# # Adding S shaped trend

# %%
Y = time / ( time+ np.exp(500-1*time)) 
signal_s = signal+Y
plt.plot(signal_s)

# %%
plt.plot(Y)
