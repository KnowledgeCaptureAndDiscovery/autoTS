# %% [markdown]
# # autoTS: Wavelet Transform
#
#
# **Table of contents**
# * Generating Data
# * Pre-processing
#     * Standardization
#     * Detrend
#     * Detect outliers
#     * Remove outliers
#     * Hypothesize over missing values
# * Analysis
#     * Wavelet transform
#     * Significance testing
#
#
# Functions are available through the [Pyleoclim package](https://github.com/LinkedEarth/Pyleoclim_util/tree/Development) on the development branch.

# %%
import pyleoclim as pyleo
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Generation
#
# Here,we use synthetic timeseries for demonstration purposes.
#
# Pyleoclim is being extended to handle LiPD files directly. For other types of data, Pyleoclim's basic object is Series, which will need to be created as a first step.
#
# ### Step 1: Generate a signal with trend, noise and missing values
#
# This step would be replaced by opening dataset.

# %%
# Generate a mixed signal with known frequencies
freqs=[1/20,1/80]
#freqs=[1/20]
time=np.arange(2001)
signals=[]
for freq in freqs:
    signals.append(np.cos(2*np.pi*freq*time))
signal=sum(signals)

# Add outliers

#outliers_start = np.mean(signal)+5*np.std(signal)
#outliers_end = np.mean(signal)+7*np.std(signal)
#outlier_values = np.arange(outliers_start,outliers_end,0.1)
#index = np.random.randint(0,len(signal),6)
#signal_out = signal
#for i,ind in enumerate(index):
#    signal_out[ind] = outlier_values[i]

# Add a non-linear trend
slope = 1e-5
intercept = -1
nonlinear_trend = slope*time**2 + intercept
signal_trend = signal + nonlinear_trend
#signal_trend = signal_out + nonlinear_trend

#Add white noise
sig_var = np.var(signal)
noise_var = sig_var / 2 #signal is twice the size of noise
white_noise = np.random.normal(0, np.sqrt(noise_var), size=np.size(signal))
signal_noise = signal_trend + white_noise

#Remove data points
del_percent = 0.4
n_del = int(del_percent*np.size(time))
deleted_idx = np.random.choice(range(np.size(time)), n_del, replace=False)
time_unevenly =  np.delete(time, deleted_idx)
signal_unevenly =  np.delete(signal_noise, deleted_idx)


#Plot
plt.plot(time_unevenly,signal_unevenly)
plt.xlabel('Time')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ### Step 2: Create a series object for Pyleoclim

# %%
ts=pyleo.Series(time=time_unevenly,value=signal_unevenly)
fig,ax=ts.plot()

# %% [markdown]
# ## Preprocessing
#
# ### Standarize

# %%
#%% preprocessing- standardize
ts_std=ts.standardize()
fig,ax=ts_std.plot()

# %% [markdown]
# ### Detrend

# %%
#%% preprocessing - detrend
    
ts_detrended=ts_std.detrend(method='emd')
fig,ax=ts_detrended.plot()
# Out:
# Mode 5, Iteration 600
# 0 minima > 0; 9 maxima < 0.
# Mode 5, Iteration 800
# 0 minima > 0; 9 maxima < 0.
# Mode 5, Iteration 1000
# 0 minima > 0; 14 maxima < 0.

# %% [markdown]
# ### Detect outliers and remove outliers
#
# Based on the detected outliers, may need to remove them prior to analysis.
#
# In this case, the if/else could happen within the component: do nothing on else but return a similar object to be used by the next component.

# %%
#%% detect and remove outliers
is_outlier=ts_detrended.detect_outliers()
if len(np.where(is_outlier==True))>0:
    ts_outliers = ts_detrended.remove_outliers()
else:
    ts_outliers=ts_detrended
fig,ax=ts_outliers.plot()

# %% [markdown]
# ### Interpolation
#
# This example uses a linear interpolation, other methods to achieve an evenly-spaced time series are spline interpolation, binning, and singular spectrum analysis. All methods could be equally valid and should be explored.
#
# **Rule**: if the method spectral analysis is 'Lomb-Scargle' or 'WWZ', this step should be skipped (or same timeseries returned); else, this step is necessary.

# %%
#%% interpolation
ts_interp=ts_outliers.interp(method='linear')
fig,ax=ts_interp.plot()

# %%
### Analysis



WWZ method doesn't require require evenly-spaced data in time, and therefore  uses the detrended time series.

# %%
#%% Analysis-cwt

scales = np.arange(1, 1000) #not sure what scales to use
cwt_res=ts_interp.wavelet(method='cwt',settings={'scales':scales})
cwt_res.plot(title='cwt')
plt.show()

# %%
#%% signif test- cwt
cwt_signif=cwt_res.signif_test(qs=[0.95])
fig,ax=cwt_signif.plot(title='cwt analysis')
plt.show()
# Out:
# Performing wavelet analysis on surrogates: 100%|██████████| 200/200 [05:28<00:00,  1.64s/it]

# %%
#%% Analysis - wwz
wwz_res=ts_detrended.wavelet(method='wwz',settings={})
wwz_res.plot(title='wwz')
plt.show()

# %%
#%% signif test -wwz
wwz_signif=wwz_res.signif_test(qs=[0.95])
fig,ax=wwz_signif.plot(title='wwz analysis')
plt.show()
# Out:
# Performing wavelet analysis on surrogates:   0%|          | 0/200 [00:00<?, ?it/s]
#
# Performing wavelet analysis on surrogates:   0%|          | 1/200 [00:22<1:16:16, 23.00s/it]
#
# Performing wavelet analysis on surrogates:   1%|          | 2/200 [00:45<1:15:35, 22.91s/it]
#
# Performing wavelet analysis on surrogates:   2%|▏         | 3/200 [01:08<1:15:04, 22.87s/it]
#
# Performing wavelet analysis on surrogates:   2%|▏         | 4/200 [01:31<1:14:47, 22.90s/it]
#
# Performing wavelet analysis on surrogates:   2%|▎         | 5/200 [01:53<1:13:58, 22.76s/it]
#
# Performing wavelet analysis on surrogates:   3%|▎         | 6/200 [02:16<1:13:48, 22.83s/it]
#
# Performing wavelet analysis on surrogates:   4%|▎         | 7/200 [02:41<1:15:03, 23.33s/it]
#
# Performing wavelet analysis on surrogates:   4%|▍         | 8/200 [03:05<1:15:54, 23.72s/it]
#
# Performing wavelet analysis on surrogates:   4%|▍         | 9/200 [03:30<1:16:26, 24.01s/it]
#
# Performing wavelet analysis on surrogates:   5%|▌         | 10/200 [03:55<1:16:33, 24.18s/it]
#
# Performing wavelet analysis on surrogates:   6%|▌         | 11/200 [04:20<1:17:01, 24.45s/it]
#
# Performing wavelet analysis on surrogates:   6%|▌         | 12/200 [04:44<1:15:58, 24.25s/it]
#
# Performing wavelet analysis on surrogates:   6%|▋         | 13/200 [05:07<1:14:18, 23.84s/it]
#
# Performing wavelet analysis on surrogates:   7%|▋         | 14/200 [05:29<1:12:55, 23.52s/it]
#
# Performing wavelet analysis on surrogates:   8%|▊         | 15/200 [05:51<1:11:17, 23.12s/it]
#
# Performing wavelet analysis on surrogates:   8%|▊         | 16/200 [06:14<1:10:40, 23.05s/it]
#
# Performing wavelet analysis on surrogates:   8%|▊         | 17/200 [06:37<1:09:52, 22.91s/it]
#
# Performing wavelet analysis on surrogates:   9%|▉         | 18/200 [07:00<1:09:12, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  10%|▉         | 19/200 [07:22<1:08:21, 22.66s/it]
#
# Performing wavelet analysis on surrogates:  10%|█         | 20/200 [07:44<1:07:54, 22.64s/it]
#
# Performing wavelet analysis on surrogates:  10%|█         | 21/200 [08:07<1:07:41, 22.69s/it]
#
# Performing wavelet analysis on surrogates:  11%|█         | 22/200 [08:30<1:07:00, 22.59s/it]
#
# Performing wavelet analysis on surrogates:  12%|█▏        | 23/200 [08:52<1:06:44, 22.63s/it]
#
# Performing wavelet analysis on surrogates:  12%|█▏        | 24/200 [09:15<1:06:21, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  12%|█▎        | 25/200 [09:38<1:06:00, 22.63s/it]
#
# Performing wavelet analysis on surrogates:  13%|█▎        | 26/200 [10:00<1:05:26, 22.57s/it]
#
# Performing wavelet analysis on surrogates:  14%|█▎        | 27/200 [10:23<1:05:08, 22.59s/it]
#
# Performing wavelet analysis on surrogates:  14%|█▍        | 28/200 [10:45<1:04:46, 22.60s/it]
#
# Performing wavelet analysis on surrogates:  14%|█▍        | 29/200 [11:08<1:04:26, 22.61s/it]
#
# Performing wavelet analysis on surrogates:  15%|█▌        | 30/200 [11:31<1:04:09, 22.64s/it]
#
# Performing wavelet analysis on surrogates:  16%|█▌        | 31/200 [11:53<1:03:40, 22.61s/it]
#
# Performing wavelet analysis on surrogates:  16%|█▌        | 32/200 [12:16<1:03:25, 22.65s/it]
#
# Performing wavelet analysis on surrogates:  16%|█▋        | 33/200 [12:38<1:02:44, 22.54s/it]
#
# Performing wavelet analysis on surrogates:  17%|█▋        | 34/200 [13:01<1:02:35, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  18%|█▊        | 35/200 [13:24<1:02:27, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  18%|█▊        | 36/200 [13:46<1:01:43, 22.58s/it]
#
# Performing wavelet analysis on surrogates:  18%|█▊        | 37/200 [14:09<1:01:29, 22.63s/it]
#
# Performing wavelet analysis on surrogates:  19%|█▉        | 38/200 [14:32<1:01:15, 22.69s/it]
#
# Performing wavelet analysis on surrogates:  20%|█▉        | 39/200 [14:54<1:00:38, 22.60s/it]
#
# Performing wavelet analysis on surrogates:  20%|██        | 40/200 [15:17<1:00:19, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  20%|██        | 41/200 [15:39<59:57, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  21%|██        | 42/200 [16:02<59:34, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  22%|██▏       | 43/200 [16:24<58:58, 22.54s/it]
#
# Performing wavelet analysis on surrogates:  22%|██▏       | 44/200 [16:47<58:41, 22.58s/it]
#
# Performing wavelet analysis on surrogates:  22%|██▎       | 45/200 [17:10<58:20, 22.58s/it]
#
# Performing wavelet analysis on surrogates:  23%|██▎       | 46/200 [17:32<57:46, 22.51s/it]
#
# Performing wavelet analysis on surrogates:  24%|██▎       | 47/200 [17:55<57:25, 22.52s/it]
#
# Performing wavelet analysis on surrogates:  24%|██▍       | 48/200 [18:17<57:14, 22.60s/it]
#
# Performing wavelet analysis on surrogates:  24%|██▍       | 49/200 [18:40<56:57, 22.63s/it]
#
# Performing wavelet analysis on surrogates:  25%|██▌       | 50/200 [19:02<56:23, 22.56s/it]
#
# Performing wavelet analysis on surrogates:  26%|██▌       | 51/200 [19:26<56:55, 22.92s/it]
#
# Performing wavelet analysis on surrogates:  26%|██▌       | 52/200 [19:50<56:54, 23.07s/it]
#
# Performing wavelet analysis on surrogates:  26%|██▋       | 53/200 [20:12<56:05, 22.90s/it]
#
# Performing wavelet analysis on surrogates:  27%|██▋       | 54/200 [20:37<57:07, 23.48s/it]
#
# Performing wavelet analysis on surrogates:  28%|██▊       | 55/200 [21:00<56:17, 23.29s/it]
#
# Performing wavelet analysis on surrogates:  28%|██▊       | 56/200 [21:23<55:31, 23.14s/it]
#
# Performing wavelet analysis on surrogates:  28%|██▊       | 57/200 [21:45<55:00, 23.08s/it]
#
# Performing wavelet analysis on surrogates:  29%|██▉       | 58/200 [22:08<54:29, 23.02s/it]
#
# Performing wavelet analysis on surrogates:  30%|██▉       | 59/200 [22:31<53:55, 22.95s/it]
#
# Performing wavelet analysis on surrogates:  30%|███       | 60/200 [22:54<53:17, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  30%|███       | 61/200 [23:17<53:06, 22.92s/it]
#
# Performing wavelet analysis on surrogates:  31%|███       | 62/200 [23:40<52:41, 22.91s/it]
#
# Performing wavelet analysis on surrogates:  32%|███▏      | 63/200 [24:02<52:00, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  32%|███▏      | 64/200 [24:25<51:42, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  32%|███▎      | 65/200 [24:48<51:23, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  33%|███▎      | 66/200 [25:11<50:50, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  34%|███▎      | 67/200 [25:33<50:32, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  34%|███▍      | 68/200 [25:57<50:19, 22.87s/it]
#
# Performing wavelet analysis on surrogates:  34%|███▍      | 69/200 [26:19<49:45, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  35%|███▌      | 70/200 [26:42<49:27, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  36%|███▌      | 71/200 [27:05<49:05, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  36%|███▌      | 72/200 [27:28<48:42, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  36%|███▋      | 73/200 [27:50<48:08, 22.74s/it]
#
# Performing wavelet analysis on surrogates:  37%|███▋      | 74/200 [28:13<47:54, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  38%|███▊      | 75/200 [28:36<47:30, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  38%|███▊      | 76/200 [28:59<46:57, 22.72s/it]
#
# Performing wavelet analysis on surrogates:  38%|███▊      | 77/200 [29:21<46:39, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  39%|███▉      | 78/200 [29:44<46:14, 22.74s/it]
#
# Performing wavelet analysis on surrogates:  40%|███▉      | 79/200 [30:07<45:57, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  40%|████      | 80/200 [30:30<45:33, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  40%|████      | 81/200 [30:53<45:13, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  41%|████      | 82/200 [31:16<44:54, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  42%|████▏     | 83/200 [31:39<44:38, 22.89s/it]
#
# Performing wavelet analysis on surrogates:  42%|████▏     | 84/200 [32:01<44:16, 22.90s/it]
#
# Performing wavelet analysis on surrogates:  42%|████▎     | 85/200 [32:24<43:51, 22.88s/it]
#
# Performing wavelet analysis on surrogates:  43%|████▎     | 86/200 [32:47<43:24, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  44%|████▎     | 87/200 [33:10<42:57, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  44%|████▍     | 88/200 [33:33<42:36, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  44%|████▍     | 89/200 [33:56<42:15, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  45%|████▌     | 90/200 [34:18<41:46, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  46%|████▌     | 91/200 [34:41<41:28, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  46%|████▌     | 92/200 [35:04<41:08, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  46%|████▋     | 93/200 [35:27<40:38, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  47%|████▋     | 94/200 [35:50<40:19, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  48%|████▊     | 95/200 [36:13<40:00, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  48%|████▊     | 96/200 [36:35<39:30, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  48%|████▊     | 97/200 [36:58<39:12, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  49%|████▉     | 98/200 [37:21<38:51, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  50%|████▉     | 99/200 [37:44<38:30, 22.88s/it]
#
# Performing wavelet analysis on surrogates:  50%|█████     | 100/200 [38:07<38:00, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  50%|█████     | 101/200 [38:30<37:44, 22.87s/it]
#
# Performing wavelet analysis on surrogates:  51%|█████     | 102/200 [38:53<37:22, 22.88s/it]
#
# Performing wavelet analysis on surrogates:  52%|█████▏    | 103/200 [39:15<36:48, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  52%|█████▏    | 104/200 [39:38<36:25, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  52%|█████▎    | 105/200 [40:01<36:03, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  53%|█████▎    | 106/200 [40:23<35:31, 22.67s/it]
#
# Performing wavelet analysis on surrogates:  54%|█████▎    | 107/200 [40:46<35:12, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  54%|█████▍    | 108/200 [41:09<34:51, 22.73s/it]
#
# Performing wavelet analysis on surrogates:  55%|█████▍    | 109/200 [41:31<34:30, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  55%|█████▌    | 110/200 [41:54<34:07, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  56%|█████▌    | 111/200 [42:17<33:49, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  56%|█████▌    | 112/200 [42:40<33:26, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  56%|█████▋    | 113/200 [43:02<32:57, 22.73s/it]
#
# Performing wavelet analysis on surrogates:  57%|█████▋    | 114/200 [43:26<32:45, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  57%|█████▊    | 115/200 [43:48<32:22, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  58%|█████▊    | 116/200 [44:11<32:00, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  58%|█████▊    | 117/200 [44:34<31:28, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  59%|█████▉    | 118/200 [44:57<31:09, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  60%|█████▉    | 119/200 [45:20<30:47, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  60%|██████    | 120/200 [45:42<30:16, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  60%|██████    | 121/200 [46:05<29:57, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  61%|██████    | 122/200 [46:28<29:38, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  62%|██████▏   | 123/200 [46:51<29:18, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  62%|██████▏   | 124/200 [47:13<28:53, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  62%|██████▎   | 125/200 [47:36<28:30, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  63%|██████▎   | 126/200 [47:59<27:59, 22.69s/it]
#
# Performing wavelet analysis on surrogates:  64%|██████▎   | 127/200 [48:22<27:41, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  64%|██████▍   | 128/200 [48:45<27:22, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  64%|██████▍   | 129/200 [49:07<27:02, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  65%|██████▌   | 130/200 [49:30<26:35, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  66%|██████▌   | 131/200 [49:53<26:13, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  66%|██████▌   | 132/200 [50:16<25:52, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  66%|██████▋   | 133/200 [50:38<25:22, 22.72s/it]
#
# Performing wavelet analysis on surrogates:  67%|██████▋   | 134/200 [51:01<25:03, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  68%|██████▊   | 135/200 [51:24<24:41, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  68%|██████▊   | 136/200 [51:47<24:16, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  68%|██████▊   | 137/200 [52:10<23:57, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  69%|██████▉   | 138/200 [52:32<23:34, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  70%|██████▉   | 139/200 [52:55<23:13, 22.84s/it]
#
# Performing wavelet analysis on surrogates:  70%|███████   | 140/200 [53:18<22:52, 22.87s/it]
#
# Performing wavelet analysis on surrogates:  70%|███████   | 141/200 [53:41<22:30, 22.88s/it]
#
# Performing wavelet analysis on surrogates:  71%|███████   | 142/200 [54:04<22:07, 22.89s/it]
#
# Performing wavelet analysis on surrogates:  72%|███████▏  | 143/200 [54:27<21:38, 22.79s/it]
#
# Performing wavelet analysis on surrogates:  72%|███████▏  | 144/200 [54:50<21:16, 22.80s/it]
#
# Performing wavelet analysis on surrogates:  72%|███████▎  | 145/200 [55:12<20:54, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  73%|███████▎  | 146/200 [55:35<20:28, 22.74s/it]
#
# Performing wavelet analysis on surrogates:  74%|███████▎  | 147/200 [55:58<20:07, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  74%|███████▍  | 148/200 [56:21<19:47, 22.83s/it]
#
# Performing wavelet analysis on surrogates:  74%|███████▍  | 149/200 [56:44<19:23, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  75%|███████▌  | 150/200 [57:07<19:12, 23.05s/it]
#
# Performing wavelet analysis on surrogates:  76%|███████▌  | 151/200 [57:30<18:48, 23.02s/it]
#
# Performing wavelet analysis on surrogates:  76%|███████▌  | 152/200 [57:53<18:17, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  76%|███████▋  | 153/200 [58:16<17:59, 22.96s/it]
#
# Performing wavelet analysis on surrogates:  77%|███████▋  | 154/200 [58:39<17:34, 22.92s/it]
#
# Performing wavelet analysis on surrogates:  78%|███████▊  | 155/200 [59:02<17:11, 22.91s/it]
#
# Performing wavelet analysis on surrogates:  78%|███████▊  | 156/200 [59:24<16:44, 22.82s/it]
#
# Performing wavelet analysis on surrogates:  78%|███████▊  | 157/200 [59:47<16:22, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  79%|███████▉  | 158/200 [1:00:10<16:00, 22.86s/it]
#
# Performing wavelet analysis on surrogates:  80%|███████▉  | 159/200 [1:00:32<15:32, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  80%|████████  | 160/200 [1:00:55<15:10, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  80%|████████  | 161/200 [1:01:18<14:48, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  81%|████████  | 162/200 [1:01:41<14:25, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  82%|████████▏ | 163/200 [1:02:04<14:03, 22.80s/it]
# Performing wavelet analysis on surrogates:  82%|████████▏ | 164/200 [1:02:27<13:43, 22.88s/it]
#
# Performing wavelet analysis on surrogates:  82%|████████▎ | 165/200 [1:02:50<13:21, 22.90s/it]
#
# Performing wavelet analysis on surrogates:  83%|████████▎ | 166/200 [1:03:12<12:55, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  84%|████████▎ | 167/200 [1:03:35<12:32, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  84%|████████▍ | 168/200 [1:03:58<12:08, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  84%|████████▍ | 169/200 [1:04:20<11:43, 22.70s/it]
#
# Performing wavelet analysis on surrogates:  85%|████████▌ | 170/200 [1:04:43<11:22, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  86%|████████▌ | 171/200 [1:05:06<11:00, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  86%|████████▌ | 172/200 [1:05:29<10:37, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  86%|████████▋ | 173/200 [1:05:51<10:13, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  87%|████████▋ | 174/200 [1:06:14<09:52, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  88%|████████▊ | 175/200 [1:06:37<09:30, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  88%|████████▊ | 176/200 [1:07:00<09:06, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  88%|████████▊ | 177/200 [1:07:22<08:43, 22.74s/it]
#
# Performing wavelet analysis on surrogates:  89%|████████▉ | 178/200 [1:07:45<08:21, 22.78s/it]
#
# Performing wavelet analysis on surrogates:  90%|████████▉ | 179/200 [1:08:08<07:57, 22.72s/it]
#
# Performing wavelet analysis on surrogates:  90%|█████████ | 180/200 [1:08:31<07:35, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  90%|█████████ | 181/200 [1:08:54<07:12, 22.76s/it]
#
# Performing wavelet analysis on surrogates:  91%|█████████ | 182/200 [1:09:16<06:48, 22.69s/it]
#
# Performing wavelet analysis on surrogates:  92%|█████████▏| 183/200 [1:09:39<06:26, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  92%|█████████▏| 184/200 [1:10:01<06:03, 22.70s/it]
#
# Performing wavelet analysis on surrogates:  92%|█████████▎| 185/200 [1:10:24<05:39, 22.62s/it]
#
# Performing wavelet analysis on surrogates:  93%|█████████▎| 186/200 [1:10:47<05:17, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  94%|█████████▎| 187/200 [1:11:10<04:55, 22.75s/it]
#
# Performing wavelet analysis on surrogates:  94%|█████████▍| 188/200 [1:11:32<04:32, 22.67s/it]
#
# Performing wavelet analysis on surrogates:  94%|█████████▍| 189/200 [1:11:55<04:09, 22.70s/it]
#
# Performing wavelet analysis on surrogates:  95%|█████████▌| 190/200 [1:12:18<03:47, 22.73s/it]
#
# Performing wavelet analysis on surrogates:  96%|█████████▌| 191/200 [1:12:40<03:24, 22.72s/it]
#
# Performing wavelet analysis on surrogates:  96%|█████████▌| 192/200 [1:13:03<03:01, 22.74s/it]
#
# Performing wavelet analysis on surrogates:  96%|█████████▋| 193/200 [1:13:26<02:39, 22.85s/it]
#
# Performing wavelet analysis on surrogates:  97%|█████████▋| 194/200 [1:13:49<02:16, 22.81s/it]
#
# Performing wavelet analysis on surrogates:  98%|█████████▊| 195/200 [1:14:11<01:53, 22.70s/it]
#
# Performing wavelet analysis on surrogates:  98%|█████████▊| 196/200 [1:14:34<01:30, 22.71s/it]
#
# Performing wavelet analysis on surrogates:  98%|█████████▊| 197/200 [1:14:57<01:08, 22.77s/it]
#
# Performing wavelet analysis on surrogates:  99%|█████████▉| 198/200 [1:15:20<00:45, 22.67s/it]
#
# Performing wavelet analysis on surrogates: 100%|█████████▉| 199/200 [1:15:42<00:22, 22.72s/it]
#
# Performing wavelet analysis on surrogates: 100%|██████████| 200/200 [1:16:05<00:00, 22.83s/it]
